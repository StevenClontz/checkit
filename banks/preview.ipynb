# %%
# relative path to *.sage/*.ptx files to preview
library = "clontz-diff-eq"
objective = "S1"

# loads and displays an example generated exercise
from IPython.core.display import display, HTML
oldwd=os.getcwd();os.chdir("..");load("main.sage");os.chdir(oldwd)
oldwd=os.getcwd();os.chdir(library)
load(f"{objective}.sage")
with open(f"{objective}.ptx",'r') as template_file:
    template = template_file.read()
os.chdir(oldwd)

exercise = Exercise(
    name="Test",
    slug="test",
    generator=generator,
    template=template
)
display(HTML(exercise.html()))
exercise.preview()
# Out:
# <div class="exercise">
# <div class="exercise-statement">
# <p> Draw a phase plane for the following system of ODEs. </p>
# <p>\[x'= -2 \, x + 2 \, y - 8 \]</p>
# <p>\[y'= -2 \, x - 2 \, y - 4 \]</p>
# <p>Be sure to include and label the following features in your sketch:</p>
# <ul>
# <li>The isoclines \(x'=0\) and \(y'=0\).</li>
# <li>Arrow systems describing trajectories of solutions.</li>
# <li>The equillibrium of the system.</li>
# </ul>
# </div>
# <div class="exercise-answer">
# <p><b>Answer:</b></p>
# <p> The isoclines cross at the equillibrium \( \left(-3, 1\right) \), with \(x'=0\) having a positive slope and \(y'=0\) having a negative slope. </p>
# <p> The right region has a southwest arrow system, the top region has a southeast arrow system, the left region has a northeast arrow system, and the bottom region has a northwest arrow system. </p>
# </div>
# </div>
# Data dictionary
# -----------
# {'dxdt': -2*x + 2*y - 8, 'dydt': -2*x - 2*y - 4, 'intersection': (-3, 1), 'dxdt_slope': 'positive', 'dydt_slope': 'negative', 'top_arrows': 'southeast', 'bottom_arrows': 'northwest', 'right_arrows': 'southwest', 'left_arrows': 'northeast'}
#
# Data XML
# -----------
# <data><dxdt> -2 \, x + 2 \, y - 8 </dxdt><dydt> -2 \, x - 2 \, y - 4 </dydt><intersection> \left(-3, 1\right) </intersection><dxdt_slope>positive</dxdt_slope><dydt_slope>negative</dydt_slope><top_arrows>southeast</top_arrows><bottom_arrows>northwest</bottom_arrows><right_arrows>southwest</right_arrows><left_arrows>northeast</left_arrows></data>
#
# HTML source
# -----------
# <div class="exercise">
# <div class="exercise-statement">
# <p> Draw a phase plane for the following system of ODEs. </p>
# <p>\[x'= -2 \, x + 2 \, y - 8 \]</p>
# <p>\[y'= -2 \, x - 2 \, y - 4 \]</p>
# <p>Be sure to include and label the following features in your sketch:</p>
# <ul>
# <li>The isoclines \(x'=0\) and \(y'=0\).</li>
# <li>Arrow systems describing trajectories of solutions.</li>
# <li>The equillibrium of the system.</li>
# </ul>
# </div>
# <div class="exercise-answer">
# <p><b>Answer:</b></p>
# <p> The isoclines cross at the equillibrium \( \left(-3, 1\right) \), with \(x'=0\) having a positive slope and \(y'=0\) having a negative slope. </p>
# <p> The right region has a southwest arrow system, the top region has a southeast arrow system, the left region has a northeast arrow system, and the bottom region has a northwest arrow system. </p>
# </div>
# </div>
#
#
# LaTeX source
# ------------
#
# \begin{exerciseStatement}
#
#
#  Draw a phase plane for the following system of ODEs.
#
# \[x'= -2 \, x + 2 \, y - 8 \]\[y'= -2 \, x - 2 \, y - 4 \]
#
# Be sure to include and label the following features in your sketch:
#
#
# \begin{itemize}
# \item The isoclines \(x'=0\) and \(y'=0\).
# \item Arrow systems describing trajectories of solutions.
# \item The equillibrium of the system.
# \end{itemize}
#
# \end{exerciseStatement}
#
# \begin{exerciseAnswer}
#
#
#  The isoclines cross at the equillibrium \( \left(-3, 1\right) \), with \(x'=0\) having a positive slope and \(y'=0\) having a negative slope.
#
#
#
#  The right region has a southwest arrow system, the top region has a southeast arrow system, the left region has a northeast arrow system, and the bottom region has a northwest arrow system.
#
#
# \end{exerciseAnswer}
#
#
# QTI source
# ------------
# <item ident="test-8086" title="test | Test | ver. 8086">
#   <itemmetadata>
#     <qtimetadata>
#       <qtimetadatafield>
#         <fieldlabel>question_type</fieldlabel>
#         <fieldentry>essay_question</fieldentry>
#       </qtimetadatafield>
#     </qtimetadata>
#   </itemmetadata>
#   <presentation>
#     <material>
#       <mattextxml>
#         <div class="exercise-statement">
#           <p>
#             <strong>test.</strong>
#           </p>
#           <p> Draw a phase plane for the following system of ODEs. </p>
#           <p style="text-align:center;">
#             <img style="border:1px #ddd solid;padding:5px;border-radius:5px;" src="https://latex.codecogs.com/svg.latex?x'= -2 \, x + 2 \, y - 8" alt="x'= -2 \, x + 2 \, y - 8" title="x'= -2 \, x + 2 \, y - 8" data-latex="x'= -2 \, x + 2 \, y - 8"/>
#           </p>
#           <p style="text-align:center;">
#             <img style="border:1px #ddd solid;padding:5px;border-radius:5px;" src="https://latex.codecogs.com/svg.latex?y'= -2 \, x - 2 \, y - 4" alt="y'= -2 \, x - 2 \, y - 4" title="y'= -2 \, x - 2 \, y - 4" data-latex="y'= -2 \, x - 2 \, y - 4"/>
#           </p>
#           <p>Be sure to include and label the following features in your sketch:</p>
#           <ul>
#             <li>The isoclines <img style="border:1px #ddd solid;padding:5px;border-radius:5px;" src="https://latex.codecogs.com/svg.latex?x'=0" alt="x'=0" title="x'=0" data-latex="x'=0"/> and <img style="border:1px #ddd solid;padding:5px;border-radius:5px;" src="https://latex.codecogs.com/svg.latex?y'=0" alt="y'=0" title="y'=0" data-latex="y'=0"/>.</li>
#             <li>Arrow systems describing trajectories of solutions.</li>
#             <li>The equillibrium of the system.</li>
#           </ul>
#         </div>
#       </mattextxml>
#       <mattext texttype="text/html">&lt;div class="exercise-statement"&gt;
#   &lt;p&gt;
#     &lt;strong&gt;test.&lt;/strong&gt;
#   &lt;/p&gt;
#   &lt;p&gt; Draw a phase plane for the following system of ODEs. &lt;/p&gt;
#   &lt;p style="text-align:center;"&gt;
#     &lt;img style="border:1px #ddd solid;padding:5px;border-radius:5px;" src="https://latex.codecogs.com/svg.latex?x'=%20-2%20%5C,%20x%20+%202%20%5C,%20y%20-%208" alt="x'= -2 \, x + 2 \, y - 8" title="x'= -2 \, x + 2 \, y - 8" data-latex="x'= -2 \, x + 2 \, y - 8"&gt;
#   &lt;/p&gt;
#   &lt;p style="text-align:center;"&gt;
#     &lt;img style="border:1px #ddd solid;padding:5px;border-radius:5px;" src="https://latex.codecogs.com/svg.latex?y'=%20-2%20%5C,%20x%20-%202%20%5C,%20y%20-%204" alt="y'= -2 \, x - 2 \, y - 4" title="y'= -2 \, x - 2 \, y - 4" data-latex="y'= -2 \, x - 2 \, y - 4"&gt;
#   &lt;/p&gt;
#   &lt;p&gt;Be sure to include and label the following features in your sketch:&lt;/p&gt;
#   &lt;ul&gt;
#     &lt;li&gt;The isoclines &lt;img style="border:1px #ddd solid;padding:5px;border-radius:5px;" src="https://latex.codecogs.com/svg.latex?x'=0" alt="x'=0" title="x'=0" data-latex="x'=0"&gt; and &lt;img style="border:1px #ddd solid;padding:5px;border-radius:5px;" src="https://latex.codecogs.com/svg.latex?y'=0" alt="y'=0" title="y'=0" data-latex="y'=0"&gt;.&lt;/li&gt;
#     &lt;li&gt;Arrow systems describing trajectories of solutions.&lt;/li&gt;
#     &lt;li&gt;The equillibrium of the system.&lt;/li&gt;
#   &lt;/ul&gt;
# &lt;/div&gt;
#
# </mattext>
#     </material>
#     <response_str ident="response1" rcardinality="Single">
#       <render_fib>
#         <response_label ident="answer1" rshuffle="No"/>
#       </render_fib>
#     </response_str>
#   </presentation>
#   <itemfeedback ident="general_fb">
#     <flow_mat>
#       <material>
#         <mattextxml>
#           <div class="exercise-answer">
#             <h4>Partial Answer:</h4>
#             <p> The isoclines cross at the equillibrium <img style="border:1px #ddd solid;padding:5px;border-radius:5px;" src="https://latex.codecogs.com/svg.latex?\left(-3, 1\right)" alt="\left(-3, 1\right)" title="\left(-3, 1\right)" data-latex="\left(-3, 1\right)"/>, with <img style="border:1px #ddd solid;padding:5px;border-radius:5px;" src="https://latex.codecogs.com/svg.latex?x'=0" alt="x'=0" title="x'=0" data-latex="x'=0"/> having a positive slope and <img style="border:1px #ddd solid;padding:5px;border-radius:5px;" src="https://latex.codecogs.com/svg.latex?y'=0" alt="y'=0" title="y'=0" data-latex="y'=0"/> having a negative slope. </p>
#             <p> The right region has a southwest arrow system, the top region has a southeast arrow system, the left region has a northeast arrow system, and the bottom region has a northwest arrow system. </p>
#           </div>
#         </mattextxml>
#         <mattext texttype="text/html">&lt;div class="exercise-answer"&gt;
#   &lt;h4&gt;Partial Answer:&lt;/h4&gt;
#   &lt;p&gt; The isoclines cross at the equillibrium &lt;img style="border:1px #ddd solid;padding:5px;border-radius:5px;" src="https://latex.codecogs.com/svg.latex?%5Cleft(-3,%201%5Cright)" alt="\left(-3, 1\right)" title="\left(-3, 1\right)" data-latex="\left(-3, 1\right)"&gt;, with &lt;img style="border:1px #ddd solid;padding:5px;border-radius:5px;" src="https://latex.codecogs.com/svg.latex?x'=0" alt="x'=0" title="x'=0" data-latex="x'=0"&gt; having a positive slope and &lt;img style="border:1px #ddd solid;padding:5px;border-radius:5px;" src="https://latex.codecogs.com/svg.latex?y'=0" alt="y'=0" title="y'=0" data-latex="y'=0"&gt; having a negative slope. &lt;/p&gt;
#   &lt;p&gt; The right region has a southwest arrow system, the top region has a southeast arrow system, the left region has a northeast arrow system, and the bottom region has a northwest arrow system. &lt;/p&gt;
# &lt;/div&gt;
#
# </mattext>
#       </material>
#     </flow_mat>
#   </itemfeedback>
# </item>
#
#
# PreTeXt source
# ------------
# <exercise masterit-seed="8086" masterit-slug="test" masterit-name="Test"><statement><p>
#       Draw a phase plane for the following system of ODEs.
#     </p><me>x'= -2 \, x + 2 \, y - 8 </me><me>y'= -2 \, x - 2 \, y - 4 </me><p>Be sure to include and label the following features in your sketch:</p><ul><li>The isoclines <m>x'=0</m> and <m>y'=0</m>.</li><li>Arrow systems describing trajectories of solutions.</li><li>The equillibrium of the system.</li></ul></statement><answer><p>
#       The isoclines cross at the equillibrium <m> \left(-3, 1\right) </m>,
#       with <m>x'=0</m> having a positive slope
#       and <m>y'=0</m> having a negative slope.
#     </p><p>
#       The right region has a southwest arrow system,
#       the top region has a southeast arrow system,
#       the left region has a northeast arrow system, and
#       the bottom region has a northwest arrow system.
#     </p></answer></exercise>
